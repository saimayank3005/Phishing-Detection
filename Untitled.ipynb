# %%
import whois
def get_whois_data(domain_name):
    try:
        whois_data = whois.whois(domain_name)
        return whois_data
    except Exception as e:
        print("Error:", e)
        return None

# %%
import pandas as pd

# %%
data = pd.read_csv('verified_online.csv')
data
# Out:
#        phish_id                                                url  \
# 0       8446675           http://accesso.91-92-254-219.cprapid.com
# 1       8446671  https://cloudflare-ipfs.com/ipfs/bafybeigghtyr...
# 2       8446670                         https://allegroinform.com/
# 3       8446669  https://allegroinform.com/product/?ad=delivery...
# 4       8446667                             https://push-akt2.net/
# ...         ...                                                ...
# 46531   3573703   http://www.ezblox.site/free/jennifer111/helpdesk
# 46532   2042606  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...
# 46533   1865971  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...
# 46534   1460953       http://www.habbocreditosparati.blogspot.com/
# 46535   1123978  http://creditiperhabbogratissicuro100.blogspot...
#
#                                         phish_detail_url  \
# 0      http://www.phishtank.com/phish_detail.php?phis...
# ...

# %%
phishurl = data.sample(n = 5000, random_state = 12).copy()
phishurl = phishurl.reset_index(drop=True)
phishurl.head()
# Out:
#    phish_id                                                url  \
# 0   8187024  https://docs.google.com/presentation/d/e/2PACX...
# 1   8399620           https://s-teamg.com/p/wvc-jtrd/vrawqtgf/
# 2   8344943  https://cloudflare-ipfs.com/ipfs/bafybeibnczkx...
# 3   8216497  https://bafybeictw2hplh3akxmcbsiibnh6lrp7xgw7m...
# 4   8323078                     https://brwtihfyemdrt.web.app/
#
#                                     phish_detail_url  \
# 0  http://www.phishtank.com/phish_detail.php?phis...
# 1  http://www.phishtank.com/phish_detail.php?phis...
# 2  http://www.phishtank.com/phish_detail.php?phis...
# 3  http://www.phishtank.com/phish_detail.php?phis...
# 4  http://www.phishtank.com/phish_detail.php?phis...
#
#              submission_time verified          verification_time online target
# 0  2023-06-19T17:33:27+00:00      yes  2023-06-19T17:43:15+00:00    yes  Other
# 1  2023-12-21T09:02:07+00:00      yes  2023-12-21T09:14:28+00:00    yes  Other
# ...

# %%
features = []
label = 0

for i in range(0, 500):
    url = phishurl['url'][i]
    u=get_whois_data(url)
    features.append(u)
# Out:
# Error: No match for "INTZUHSIENNI.WIXSITE.COM".
# >>> Last update of whois database: 2024-04-01T13:05:37Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# ...

# %%
phishurl.iloc[100]
# Out:
# phish_id                                                       8400316
# url                  https://hello-world-restless-cloud-79b9.mcaunt...
# phish_detail_url     http://www.phishtank.com/phish_detail.php?phis...
# submission_time                              2023-12-22T05:52:51+00:00
# verified                                                           yes
# verification_time                            2023-12-22T06:12:58+00:00
# online                                                             yes
# target                                                       Microsoft
# Name: 100, dtype: object

# %%
print(get_whois_data('https://hello-world-restless-cloud-79b9.mcaunt'))
# Out:
# {
#   "domain_name": null,
#   "registrar": null,
#   "whois_server": null,
#   "referral_url": null,
#   "updated_date": null,
#   "creation_date": null,
#   "expiration_date": null,
#   "name_servers": null,
#   "status": null,
#   "emails": null,
#   "dnssec": null,
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "registrant_postal_code": null,
#   "country": null
# }

# %%
from datetime import datetime

# Define the current date
current_date = datetime.now()

# Initialize a list to store domain ages
domain_ages = []

# Iterate over each WHOIS record in the features list
for record in features:
    # Check if the record is not None
    if record is not None:
        # Get the creation date(s) of the domain
        creation_dates = record.get('creation_date')
        
        # If creation_dates is not None
        if creation_dates:
            # If creation_dates is a list of datetime objects
            if isinstance(creation_dates, list):
                # Extract the earliest creation date
                creation_date = min(creation_dates)
            # If creation_dates is a single datetime object
            elif isinstance(creation_dates, datetime):
                creation_date = creation_dates
            # Calculate the age of the domain in months
            domain_age_months = (current_date.year - creation_date.year) * 12 + current_date.month - creation_date.month
            # Append the domain age in months to the list
            domain_ages.append(domain_age_months)
        else:
            # If creation date is not available, append 0
            domain_ages.append(0)
    else:
        # If record is None, append 0 to indicate missing data
        domain_ages.append(0)

# Print the list of domain ages
print("Domain Ages (in months or 0 if not available):", domain_ages)
# Out:
# Domain Ages (in months or 0 if not available): [319, 7, 71, 64, 0, 168, 71, 64, 319, 319, 61, 0, 61, 6, 0, 20, 191, 0, 0, 6, 0, 136, 71, 14, 87, 71, 136, 86, 278, 136, 166, 0, 0, 278, 64, 191, 0, 71, 0, 2, 319, 0, 0, 319, 64, 278, 0, 9, 79, 0, 136, 95, 0, 0, 71, 64, 319, 166, 80, 166, 12, 102, 449, 319, 64, 136, 71, 8, 0, 136, 117, 0, 136, 0, 166, 71, 119, 449, 2, 20, 321, 319, 20, 0, 0, 125, 0, 191, 136, 26, 449, 0, 64, 26, 319, 0, 0, 136, 166, 278, 0, 217, 64, 136, 26, 0, 0, 0, 136, 136, 136, 136, 70, 0, 94, 64, 319, 119, 136, 267, 64, 64, 11, 3, 0, 0, 0, 449, 0, 0, 347, 166, 64, 136, 0, 319, 210, 0, 13, 95, 0, 61, 0, 132, 10, 3, 64, 86, 71, 64, 64, 300, 20, 0, 0, 127, 217, 0, 0, 0, 64, 64, 449, 20, 136, 319, 136, 0, 3, 0, 11, 64, 210, 217, 64, 0, 26, 20, 71, 136, 64, 20, 0, 111, 73, 319, 0, 71, 132, 20, 217, 0, 109, 26, 217, 71, 64, 28, 64, 71, 59, 95, 0, 26, 26, 3, 117, 39, 64, 0, 319, 7, 8, 39, 0, 449, 0, 64, 0, 319, 71, 88, 20, 0, 26, 71, 39, 3, 64, 319, 321, 0, 20, 319, 319, 7
# ...

# %%
features[4]

# %%
u = get_whois_data('PARTICULARES-NETBANCOSANTANDER.FIREBASEAPP.COM')
# Out:
# Error: No match for "PARTICULARES-NETBANCOSANTANDER.FIREBASEAPP.COM".
# >>> Last update of whois database: 2024-04-01T13:04:19Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# ...

# %%
print(u)
# Out:
# None

# %%
data1 = pd.read_csv('Benign_list_big_final.csv')
data1.columns = ['URLs']
legiurl = data1.sample(n = 5000, random_state = 12).copy() 
legiurl = legiurl.reset_index(drop=True)
legiurl.head()
# Out:
#                                                 URLs
# 0  http://graphicriver.net/search?date=this-month...
# 1  http://ecnavi.jp/redirect/?url=http://www.cros...
# 2  https://hubpages.com/signin?explain=follow+Hub...
# 3  http://extratorrent.cc/torrent/4190536/AOMEI+B...
# 4  http://icicibank.com/Personal-Banking/offers/o...

# %%
legi_features = []
label = 0

for i in range(0, 100):
    url = phishurl['url'][i]
    u=get_whois_data(url)
    legi_features.append(u)
# Out:
# Error: No match for "INTZUHSIENNI.WIXSITE.COM".
# >>> Last update of whois database: 2024-04-01T13:21:57Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# ...

# %%
# Define the current date
current_date = datetime.now()

# Initialize a list to store domain ages
domain_ages_legi = []

# Iterate over each WHOIS record in the features list
for record in legi_features:
    # Check if the record is not None
    if record is not None:
        # Get the creation date(s) of the domain
        creation_dates = record.get('creation_date')
        
        # If creation_dates is not None
        if creation_dates:
            # If creation_dates is a list of datetime objects
            if isinstance(creation_dates, list):
                # Extract the earliest creation date
                creation_date = min(creation_dates)
            # If creation_dates is a single datetime object
            elif isinstance(creation_dates, datetime):
                creation_date = creation_dates
            # Calculate the age of the domain in months
            domain_age_months = (current_date.year - creation_date.year) * 12 + current_date.month - creation_date.month
            # Append the domain age in months to the list
            domain_ages_legi.append(domain_age_months)
        else:
            # If creation date is not available, append 0
            domain_ages_legi.append(0)
    else:
        # If record is None, append 0 to indicate missing data
        domain_ages_legi.append(0)

# Print the list of domain ages
print("Domain Ages (in months or 0 if not available):", domain_ages_legi)
# Out:
# Domain Ages (in months or 0 if not available): [319, 7, 71, 64, 0, 168, 71, 64, 319, 319, 61, 0, 61, 6, 0, 20, 191, 0, 0, 6, 0, 136, 71, 14, 87, 71, 136, 86, 278, 136, 166, 0, 0, 278, 64, 191, 0, 71, 0, 2, 319, 0, 0, 319, 64, 278, 0, 9, 79, 0, 136, 95, 0, 0, 71, 64, 319, 166, 80, 166, 12, 102, 449, 319, 64, 136, 71, 8, 0, 136, 117, 0, 136, 0, 166, 71, 119, 449, 2, 20, 321, 319, 20, 0, 0, 125, 0, 191, 136, 26, 449, 0, 64, 26, 319, 0, 0, 136, 166, 278]

# %%
# Initialize a list to store the classifications
classifications = []
phish=0
legi=0
# Iterate over each WHOIS record in the features list
for record in features:
    # Check if the record is not None
    if record is not None:
        # Check if creation_date is missing or empty
        if not record.get('creation_date'):
            # If creation_date is missing or empty, classify as "Phishing"
            classifications.append("Phishing")
            phish+=1
        else:
            # If creation_date is available, classify as "Legitimate"
            classifications.append("Legitimate")
            legi+=1
    else:
        # If record is None, classify as "Phishing" due to missing data
        classifications.append("Phishing")

# Print the list of classifications
print("Website Classifications:", classifications)
print(phish,legi)
# Out:
# Website Classifications: ['Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Phishing', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Phishing', 'Legitimate', 'Legitimate', 'Phishing', 'Legitimate', 'Legitimate', 'Phishing', 'Phishing', 'Legitimate', 'Phishing', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Phishing', 'Phishing', 'Legitimate', 'Legitimate', 'Legitimate', 'Phishing', 'Legitimate', 'Phishing', 'Legitimate', 'Legitimate', 'Phishing', 'Phishing', 'Legitimate', 'Legitimate', 'Legitimate', 'Phishing', 'Legitimate', 'Legitimate', 'Phishing', 'Legitimate', 'Legitimate', 'Phishing', 'Phishing', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Legitimate', 'Phishing', 'Legitimate', 'Legitimate', 'Phishing', 
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse

def check_favicon(url):
    try:
        # Send a GET request to the URL
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch {url}. Status code: {response.status_code}")
            return None

        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the favicon link tag
        favicon_links = soup.find_all('link', rel=['icon', 'shortcut icon'])

        if not favicon_links:
            # Favicon not found, consider it legitimate
            return "Legitimate"

        # Extract the href attribute value
        favicon_url = favicon_links[0].get('href')

        # Parse the domain from the URL
        domain = urlparse(url).netloc

        # Parse the domain from the favicon URL
        favicon_domain = urlparse(favicon_url).netloc

        if domain != favicon_domain:
            # Favicon loaded from external domain, consider it phishing
            return "Phishing"
        else:
            # Favicon loaded from same domain, consider it legitimate
            return "Legitimate"
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

# Example usage
url = "https://auroradev.online/"
classification = check_favicon(url)
if classification is not None:
    print(f"The website {url} is classified as: {classification}")
else:
    print(f"Failed to classify {url}")
# Out:
# The website https://auroradev.online/ is classified as: Phishing

# %%
def domainAge(domain_name):
    creation_date = domain_name.creation_date
    expiration_date = domain_name.expiration_date

    if isinstance(creation_date, str) or isinstance(expiration_date, str):
        try:
            creation_date = datetime.strptime(creation_date, '%Y-%m-%d')
            expiration_date = datetime.strptime(expiration_date, '%Y-%m-%d')
        except:
            return 1

    if expiration_date is None or creation_date is None:
        return 1
    elif type(expiration_date) is list or type(creation_date) is list:
        return 1
    else:
        age_of_domain = abs((expiration_date - creation_date).days)
        if age_of_domain / 30 < 6:
            age = 1
        else:
            age = 0
        return age

# %%
import urllib
import urllib.request
domain_name = whois.whois(urlparse("https://www.google.com").netloc)
domain_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import urllib
#       2 import urllib.request
# ----> 3 domain_name = whois.whois(urlparse("https://www.google.com").netloc)
#       4 domain_name
#
# NameError: name 'urlparse' is not defined
